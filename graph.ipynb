# %%
import pandas as pd
import flask
from flask import request, jsonify
import lucene as lucene

# %%
class LuceneMain():
    def __init__(self, path):
        self.df = pd.read_csv(path)
        self.df.dropna(subset=['Summary'], inplace=True)
        self.df.drop_duplicates(subset='Name_of_Covered_Entity', keep='first', inplace=True)
        self.df.rename(columns={'Unnamed: 0':'Index'}, inplace=True)
        
        self.ix = lucene.create_index(self.df)
        
    def search(self, query_str):
        return lucene.search(query_str=query_str, ix=self.ix, df=self.df)
    
    def save_rating(self, query_str, number, rating):
        self.df = lucene.save_rating(query_str, number, rating, self.df)

# %%
path = 'cyber-security-breaches-data/Cyber Security Breaches.csv'
security_breach = LuceneMain(path)
security_breach.df
# Out:
#      Index  Number                             Name_of_Covered_Entity State  \
# 0        1       0                         Brooke Army Medical Center    TX
# 1        2       1          Mid America Kidney Stone Association, LLC    MO
# 3        4       3  Health Services for Children with Special Need...    DC
# 4        5       4                           L. Douglas Carlson, M.D.    CA
# 5        6       5                                 David I. Cohen, MD    CA
# 6        7       6                            Michele Del Vicario, MD    CA
# 7        8       7                                Joseph F. Lopez, MD    CA
# 8        9       8                                  Mark D. Lurie, MD    CA
# 9       10       9               City of Hope National Medical Center    CA
# 11      12      11               Cogent Healthcare of Wisconsin, S.C.    TN
# 12      13      12                                 Universal American    NY
# ...

# %%
def max_n(lst):
    max = 0
    if lst > max:
        max = lst
    return max

security_breach.df['Index'].apply(len).idxmax(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-dd7bb3cfebb6> in <module>
#       5     return max
#       6
# ----> 7 security_breach.df['Index'].apply(len).idxmax(axis=0)
#
# ~/miniconda3/envs/project/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()

# %%
# security_breach.save_rating('computer', 8, 5)

# %%
security_breach.search('computer')
# Out:
# [{'Score': 8.69,
#   'NewScore': 8.69,
#   'Number': '6',
#   'Entity': 'Michele Del Vicario, MD',
#   'Type': 'Theft',
# ...

# %%
(0.3+LOG10(10+views)/LOG10(10+(SELECT MAX(views) FROM Pages)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import log

x = np.linspace(0,5,100)
default_score = 2
base = 10
# boostFactor
# maxRampFactor
# curveAdjustmentFactor

y = 

y1 =  1 * (log(x)/log(10) )
y2 =  5 * (2 * log(x/2 - 0 )/log(10) ) # 
y3 =  5 * (log(x/2 - 0 )/log(30) )
y4 =  5 * (0.5 * log(x/2 - 0 )/log(10) )
plt.title('Graph of log')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.plot(x, y, '-.r', label='boost')
plt.plot(x, y2,'-.g', label='original')
plt.plot(x, y3,'-b', label='original')
plt.plot(x, y4,'-.y', label='original')
plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# /home/weiyee/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
#
# /home/weiyee/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# /home/weiyee/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()
# /home/weiyee/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import log

x = np.linspace(0,5,100)
default_score = 2
base = 10
# boostFactor
# maxRampFactor
# curveAdjustmentFactor

views = 5



y1 =  0.3+log(10+x)/log(10+(5))
y2 =  log(10+x)/log(10+(5))
y3 =  0.7 + log(10+x)/log(10+(5))
y4 =  (0.7 + log(10+x)/log(10+(5))) * 0.7
y5 =  (log(10+x)/log(10+(5))) * 0.7


plt.title('Graph of log')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.plot(x, y1, '-.r', label='boost')
plt.plot(x, y2,'-.g', label='original')
plt.plot(x, y3,'-b', label='original')
plt.plot(x, y4,'-.y', label='original')
plt.plot(x, y5, '-.m', label='without')
plt.legend(loc='upper left')
plt.grid()
plt.show()
# y k
